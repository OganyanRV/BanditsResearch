# %% [markdown]
# # Bandit benchmark notebook
#
# Этот ноутбук запускает benchmark-пайплайн (аналогично `src/run_benchmark.py`) на вашем датасете.

# %% [markdown]
# ## 1) Настройки

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import polars as pl

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from run_benchmark import load_dataset
from bandit_benchmark import (
    CatBoostPolicy,
    CustomTreeThompsonSamplingPolicyUpdateV1,
    LogisticTSLibPolicy,
    LaplaceThompsonViaBayesianLogRegPolicy,
    NeuralLaplaceThompsonViaBayesianLogRegPolicy,
    PartitionedTSLibPolicy,
    RandomPolicy,
    EpsilonGreedyPolicy,
    UCBPolicy,
    ThompsonSamplingPolicy,
    TreeThompsonSamplingPolicy,
    TreeThompsonSamplingPolicyDummyRefit,
    TreeThompsonSamplingPolicyUpdateV1,
    TreeThompsonSamplingPolicyUpdateV3,
    _NeuralActionRewardEncoder,
    build_expected_reward_estimator,
    default_scenario,
    default_five_scenarios,
    make_simulated_environment,
    preprocess_bandit_dataframe,
    run_scenarios,
    run_scenarios_ips,
    split_train_test_by_date,
)
from prepare_datasets import stage1_make_splits, stage2_scale_features

# %%
# Укажите путь к данным (.tsv или .parquet)
DATA_PATH = ROOT / 'data' / 'cdp_music_fs_small.tsv'
DATASET_NAME = DATA_PATH.stem
ARTIFACTS_DIR = ROOT / 'artifacts' / DATASET_NAME
DATASETS_DIR = ARTIFACTS_DIR / 'datasets'
PREPARED_TRAIN_PATH = DATASETS_DIR / 'train_variant_1_scaled.parquet'
PREPARED_TEST_PATH = DATASETS_DIR / 'test_variant_1_scaled.parquet'
USE_PREPARED_SPLITS = True
TRAIN_DAYS = 20
EPSILON = 0.1
SEED = 42
SIMULATE = False
STOCHASTIC_SIM = True
FULL_SCENARIOS = False
NEURAL_HIDDEN_DIMS = [128, 68]
USE_SAMPLED_DATASET = True
SAMPLE_FRACTION = 0.2  # доля строк для train/test при демо-прогоне
USE_CUSTOM_ENCODER = True
ENCODER_REP_DIM = 32
ENCODER_NN_LR = 1e-3
ENCODER_TRAIN_DATA_MODE = 'random_half'  # all | random_half | time_half


BOOTSTRAP_ENABLED = True
BOOTSTRAP_ITERATIONS = 100
BOOTSTRAP_CI = 0.95


TREE_UPDATE_C_MIN_GRID = [1, 5]
TREE_UPDATE_MIN_SAMPLES_LEAF_GRID = [150, 300]
TREE_UPDATE_MAX_DEPTH_GRID = [3, 4]

# %% [markdown]
# ## 2) Загрузка и препроцессинг

# %%
if USE_PREPARED_SPLITS and PREPARED_TRAIN_PATH.exists() and PREPARED_TEST_PATH.exists():
    train_df = pl.read_parquet(PREPARED_TRAIN_PATH)
    test_df = pl.read_parquet(PREPARED_TEST_PATH)
    print('loaded prepared splits')
else:
    # Stage 1: load -> split -> filter -> save
    train_s1, test_s1 = stage1_make_splits(str(DATA_PATH), str(DATASETS_DIR), TRAIN_DAYS, SEED)
    # Stage 2: scale features and save prepared datasets
    train_final, test_final = stage2_scale_features(train_s1, test_s1, str(DATASETS_DIR))
    train_df = pl.read_parquet(train_final)
    test_df = pl.read_parquet(test_final)

print('train:', train_df.height, 'test(random only):', test_df.height)
# Out:
# loaded prepared splits
# train: 1772191 test(random only): 3241836

# %% [markdown]
# ## 3) Конфиг политик и сценариев

# %%
policy_factories = {
    'thompson_sampling': lambda: ThompsonSamplingPolicy(seed=SEED),
}

TREE_V3_RETRAIN_EVERY_GRID = [20, 10, 10000]
TREE_V3_C_MIN_GRID = [20, 100]
TREE_V3_MIN_SAMPLES_LEAF_GRID = [3000, 5000, None]
TREE_V3_MAX_DEPTH_GRID = [3]
TREE_v3_USE_CMIN_FALLBACK_GRID = [True, False]

try:
    import sklearn  # noqa: F401
    for retrain_every_n_updates in TREE_V3_RETRAIN_EVERY_GRID:
        for c_min in TREE_V3_C_MIN_GRID:
            for min_samples_leaf in TREE_V3_MIN_SAMPLES_LEAF_GRID:
                for max_depth in TREE_V3_MAX_DEPTH_GRID:
                    for fallback in TREE_v3_USE_CMIN_FALLBACK_GRID:
                        key = (
                            f'tree_thompson_sampling_update_v3_'
                            f'r{retrain_every_n_updates}_d{max_depth}_l{min_samples_leaf}_c{c_min}_fallback{fallback}'
                        )
                        policy_factories[key] = (
                            lambda retrain_every_n_updates=retrain_every_n_updates, c_min=c_min,
                            min_samples_leaf=min_samples_leaf, max_depth=max_depth:
                            TreeThompsonSamplingPolicyUpdateV3(
                                random_state=SEED,
                                retrain_every_n_updates=retrain_every_n_updates,
                                c_min=c_min,
                                min_samples_leaf=min_samples_leaf,
                                max_depth=max_depth,
                                use_c_min_fallback=fallback
                            )
                        )
except Exception:
    print('sklearn is unavailable: skipping TreeThompsonSamplingPolicy sweeps')

from  bandit_benchmark_eval import ScenarioConfig

scenarios = [
        # ScenarioConfig("case_2_random_pretrain_online_update_daily", "random", True, "daily"),
        ScenarioConfig("case_2b_random_pretrain_online_update_step_2p5", "random", True, "step_2p5"),
    ]

# %% [markdown]
# ## 4) Запуск benchmark

# %% [markdown]
# ## 4.1) Опциональный сэмпл для быстрого прогона

# %%
if USE_SAMPLED_DATASET:
    if not (0.0 < SAMPLE_FRACTION <= 1.0):
        raise ValueError('SAMPLE_FRACTION must be in (0, 1]')
    train_eval_df = train_df.sample(fraction=SAMPLE_FRACTION, shuffle=True, seed=SEED).sort('date')
    test_eval_df = test_df.sample(fraction=SAMPLE_FRACTION, shuffle=True, seed=SEED).sort('date')
else:
    train_eval_df = train_df
    test_eval_df = test_df

print('eval train rows:', train_eval_df.height, 'of', train_df.height)
print('eval test rows:', test_eval_df.height, 'of', test_df.height)
# Out:
# eval train rows: 354438 of 1772191
# eval test rows: 648367 of 3241836

# %%
env_reward = None
if SIMULATE:
    expected_fn = build_expected_reward_estimator(train_df)
    env_reward = make_simulated_environment(
        proba_predictor=expected_fn,
        stochastic=STOCHASTIC_SIM,
        seed=SEED,
    )

result = run_scenarios(
    train_df=train_eval_df,
    test_df=test_eval_df,
    policy_factories=policy_factories,
    scenarios=scenarios,
    env_reward=env_reward,
    show_progress=True,
)

metrics_df = result['metrics']
history_df = result['history']
action_stats_df = result['action_stats']
action_daily_stats_df = result['action_daily_stats']
action_ips_stats_df = result['action_ips_stats']

display(metrics_df.sort_values('ips_ctr', ascending=False).reset_index(drop=True))

ips_snips_cols = ['scenario', 'algo', 'impressions_total', 'impressions_extrapolated', 'ips_ctr', 'snips_ctr']
if set(ips_snips_cols).issubset(metrics_df.columns):
    print('IPS/SNIPS metrics (run_scenarios):')
    display(metrics_df[ips_snips_cols].sort_values(['scenario', 'algo']).reset_index(drop=True))

print('history rows:', len(history_df))
if SIMULATE:
    display(action_stats_df)
    display(action_daily_stats_df)
    display(action_ips_stats_df)
# Out:
# case_2b_random_pretrain_online_update_step_2p5/thompson_sampling:   0%| | 0/6483
# case_2b_random_pretrain_online_update_step_2p5/thompson_sampling: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l3000_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l3000_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l5000_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l5000_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_lNone_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_lNone_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l3000_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l3000_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l5000_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_l5000_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_lNone_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r20_d3_lNone_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l3000_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l3000_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l5000_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l5000_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_lNone_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_lNone_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l3000_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l3000_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l5000_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_l5000_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_lNone_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10_d3_lNone_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l3000_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l3000_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l5000_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l5000_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_lNone_c20_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_lNone_c20_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l3000_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l3000_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l5000_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_l5000_c100_fallbackFalse: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_lNone_c100_fallbackTrue: train_unique_actions=51
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_
# case_2b_random_pretrain_online_update_step_2p5/tree_thompson_sampling_update_v3_r10000_d3_lNone_c100_fallbackFalse: train_unique_actions=51
#     impressions_total  impressions_used  total_reward       ctr  \
# 0              648367            475591       10292.0  0.021640
# 1              648367            475591       10292.0  0.021640
# 2              648367            475591       10292.0  0.021640
# 3              648367            475591       10292.0  0.021640
# 4              648367            475551       10289.0  0.021636
# 5              648367            475551       10289.0  0.021636
# 6              648367            475551       10289.0  0.021636
# 7              648367            475551       10289.0  0.021636
# 8              648367            475528       10275.0  0.021608
# 9              648367            475528       10275.0  0.021608
# 10             648367            475825       10269.0  0.021581
# 11             648367            475825       10269.0  0.021581
# 12             648367            475825       10269.0  0.021581
# 13             648367            475825       10269.0  0.021581
# 14             648367            475460       10268.0  0.021596
# 15             648367            475460       10268.0  0.021596
# 16             648367            475822       10268.0  0.021579
# 17             648367            475822       10268.0  0.021579
# 18             648367            475483       10260.0  0.021578
# 19             648367            475822       10268.0  0.021579
# 20             648367            475822       10268.0  0.021579
# 21             648367            475483       10260.0  0.021578
# 22             648367            475772       10261.0  0.021567
# 23             648367            475772       10261.0  0.021567
# 24             648367            475772       10261.0  0.021567
# 25             648367            475772       10261.0  0.021567
# 26             648367            475533       10269.0  0.021595
# 27             648367            475533       10269.0  0.021595
# 28             648367            475533       10269.0  0.021595
# 29             648367            475533       10269.0  0.021595
# 30             648367            475524       10248.0  0.021551
# 31             648367            475524       10248.0  0.021551
# 32             648367            475598       10251.0  0.021554
# 33             648367            475598       10251.0  0.021554
# 34             648367            475338       10253.0  0.021570
# 35             648367            475640       10250.0  0.021550
# 36             648367            475640       10250.0  0.021550
#
#     ips_weighted_reward   ips_ctr  snips_ctr  impressions_extrapolated  \
# 0               15735.0  0.024269   0.024287                  647868.0
# 1               15735.0  0.024269   0.024287                  647868.0
# 2               15735.0  0.024269   0.024287                  647868.0
# 3               15735.0  0.024269   0.024287                  647868.0
# 4               15724.0  0.024252   0.024275                  647751.0
# 5               15724.0  0.024252   0.024275                  647751.0
# 6               15724.0  0.024252   0.024275                  647751.0
# 7               15724.0  0.024252   0.024275                  647751.0
# 8               15710.0  0.024230   0.024251                  647807.0
# 9               15710.0  0.024230   0.024251                  647807.0
# 10              15676.0  0.024178   0.024172                  648522.0
# 11              15676.0  0.024178   0.024172                  648522.0
# 12              15676.0  0.024178   0.024172                  648522.0
# 13              15676.0  0.024178   0.024172                  648522.0
# 14              15672.0  0.024171   0.024202                  647554.0
# 15              15672.0  0.024171   0.024202                  647554.0
# 16              15667.0  0.024164   0.024159                  648489.0
# 17              15667.0  0.024164   0.024159                  648489.0
# 18              15667.0  0.024164   0.024187                  647733.0
# 19              15667.0  0.024164   0.024159                  648489.0
# 20              15667.0  0.024164   0.024159                  648489.0
# 21              15667.0  0.024164   0.024187                  647733.0
# 22              15655.0  0.024145   0.024147                  648320.0
# 23              15655.0  0.024145   0.024147                  648320.0
# 24              15655.0  0.024145   0.024147                  648320.0
# 25              15655.0  0.024145   0.024147                  648320.0
# 26              15652.0  0.024141   0.024165                  647711.0
# 27              15652.0  0.024141   0.024165                  647711.0
# 28              15652.0  0.024141   0.024165                  647711.0
# 29              15652.0  0.024141   0.024165                  647711.0
# 30              15650.0  0.024138   0.024158                  647810.0
# 31              15650.0  0.024138   0.024158                  647810.0
# 32              15647.0  0.024133   0.024147                  647988.0
# 33              15647.0  0.024133   0.024147                  647988.0
# 34              15645.0  0.024130   0.024176                  647138.0
# 35              15638.0  0.024119   0.024133                  648002.0
# 36              15638.0  0.024119   0.024133                  648002.0
#
#     replay_match_rate  cumulative_regret  avg_regret  cumulative_ips_regret  \
# 0            0.733521          13.649131    0.000029            5518.894636
# 1            0.733521          13.649131    0.000029            5518.894636
# 2            0.733521          13.649131    0.000029            5518.894636
# 3            0.733521          13.649131    0.000029            5518.894636
# 4            0.733460          16.188727    0.000034            5521.894636
# 5            0.733460          16.188727    0.000034            5521.894636
# 6            0.733460          16.188727    0.000034            5521.894636
# 7            0.733460          16.188727    0.000034            5521.894636
# 8            0.733424          30.745650    0.000065            5535.894636
# 9            0.733424          30.745650    0.000065            5535.894636
# 10           0.733882          41.430139    0.000087            5541.894636
# 11           0.733882          41.430139    0.000087            5541.894636
# 12           0.733882          41.430139    0.000087            5541.894636
# 13           0.733882          41.430139    0.000087            5541.894636
# 14           0.733319          35.572869    0.000075            5542.894636
# 15           0.733319          35.572869    0.000075            5542.894636
# 16           0.733878          41.999327    0.000088            5542.894636
# 17           0.733878          41.999327    0.000088            5542.894636
# 18           0.733355          44.478522    0.000094            5550.894636
# 19           0.733878          41.999327    0.000088            5542.894636
# 20           0.733878          41.999327    0.000088            5542.894636
# 21           0.733355          44.478522    0.000094            5550.894636
# 22           0.733800          48.039180    0.000101            5549.894636
# 23           0.733800          48.039180    0.000101            5549.894636
# 24           0.733800          48.039180    0.000101            5549.894636
# 25           0.733800          48.039180    0.000101            5549.894636
# 26           0.733432          35.273458    0.000074            5541.894636
# 27           0.733432          35.273458    0.000074            5541.894636
# 28           0.733432          35.273458    0.000074            5541.894636
# 29           0.733432          35.273458    0.000074            5541.894636
# 30           0.733418          56.269502    0.000118            5562.894636
# 31           0.733418          56.269502    0.000118            5562.894636
# 32           0.733532          55.259440    0.000116            5559.894636
# 33           0.733532          55.259440    0.000116            5559.894636
# 34           0.733131          44.166769    0.000093            5557.894636
# 35           0.733597          54.856032    0.000115            5560.894636
# 36           0.733597          54.856032    0.000115            5560.894636
#
#     avg_ips_regret                                        scenario  \
# 0         0.008512  case_2b_random_pretrain_online_update_step_2p5
# 1         0.008512  case_2b_random_pretrain_online_update_step_2p5
# 2         0.008512  case_2b_random_pretrain_online_update_step_2p5
# 3         0.008512  case_2b_random_pretrain_online_update_step_2p5
# 4         0.008517  case_2b_random_pretrain_online_update_step_2p5
# 5         0.008517  case_2b_random_pretrain_online_update_step_2p5
# 6         0.008517  case_2b_random_pretrain_online_update_step_2p5
# 7         0.008517  case_2b_random_pretrain_online_update_step_2p5
# 8         0.008538  case_2b_random_pretrain_online_update_step_2p5
# 9         0.008538  case_2b_random_pretrain_online_update_step_2p5
# 10        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 11        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 12        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 13        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 14        0.008549  case_2b_random_pretrain_online_update_step_2p5
# 15        0.008549  case_2b_random_pretrain_online_update_step_2p5
# 16        0.008549  case_2b_random_pretrain_online_update_step_2p5
# 17        0.008549  case_2b_random_pretrain_online_update_step_2p5
# 18        0.008561  case_2b_random_pretrain_online_update_step_2p5
# 19        0.008549  case_2b_random_pretrain_online_update_step_2p5
# 20        0.008549  case_2b_random_pretrain_online_update_step_2p5
# 21        0.008561  case_2b_random_pretrain_online_update_step_2p5
# 22        0.008560  case_2b_random_pretrain_online_update_step_2p5
# 23        0.008560  case_2b_random_pretrain_online_update_step_2p5
# 24        0.008560  case_2b_random_pretrain_online_update_step_2p5
# 25        0.008560  case_2b_random_pretrain_online_update_step_2p5
# 26        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 27        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 28        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 29        0.008547  case_2b_random_pretrain_online_update_step_2p5
# 30        0.008580  case_2b_random_pretrain_online_update_step_2p5
# 31        0.008580  case_2b_random_pretrain_online_update_step_2p5
# 32        0.008575  case_2b_random_pretrain_online_update_step_2p5
# 33        0.008575  case_2b_random_pretrain_online_update_step_2p5
# 34        0.008572  case_2b_random_pretrain_online_update_step_2p5
# 35        0.008577  case_2b_random_pretrain_online_update_step_2p5
# 36        0.008577  case_2b_random_pretrain_online_update_step_2p5
#
#                                                  algo
# 0   tree_thompson_sampling_update_v3_r10000_d3_l30...
# 1   tree_thompson_sampling_update_v3_r10000_d3_l30...
# 2   tree_thompson_sampling_update_v3_r10000_d3_l30...
# 3   tree_thompson_sampling_update_v3_r10000_d3_l30...
# 4   tree_thompson_sampling_update_v3_r20_d3_l3000_...
# 5   tree_thompson_sampling_update_v3_r20_d3_l3000_...
# 6   tree_thompson_sampling_update_v3_r20_d3_l3000_...
# 7   tree_thompson_sampling_update_v3_r20_d3_l3000_...
# 8   tree_thompson_sampling_update_v3_r10000_d3_lNo...
# 9   tree_thompson_sampling_update_v3_r10000_d3_lNo...
# 10  tree_thompson_sampling_update_v3_r20_d3_l5000_...
# 11  tree_thompson_sampling_update_v3_r20_d3_l5000_...
# 12  tree_thompson_sampling_update_v3_r20_d3_l5000_...
# 13  tree_thompson_sampling_update_v3_r20_d3_l5000_...
# 14  tree_thompson_sampling_update_v3_r10_d3_lNone_...
# 15  tree_thompson_sampling_update_v3_r10_d3_lNone_...
# 16  tree_thompson_sampling_update_v3_r10_d3_l5000_...
# 17  tree_thompson_sampling_update_v3_r10_d3_l5000_...
# 18  tree_thompson_sampling_update_v3_r20_d3_lNone_...
# 19  tree_thompson_sampling_update_v3_r10_d3_l5000_...
# 20  tree_thompson_sampling_update_v3_r10_d3_l5000_...
# 21  tree_thompson_sampling_update_v3_r20_d3_lNone_...
# 22  tree_thompson_sampling_update_v3_r10000_d3_l50...
# 23  tree_thompson_sampling_update_v3_r10000_d3_l50...
# 24  tree_thompson_sampling_update_v3_r10000_d3_l50...
# 25  tree_thompson_sampling_update_v3_r10000_d3_l50...
# 26  tree_thompson_sampling_update_v3_r10_d3_l3000_...
# 27  tree_thompson_sampling_update_v3_r10_d3_l3000_...
# 28  tree_thompson_sampling_update_v3_r10_d3_l3000_...
# 29  tree_thompson_sampling_update_v3_r10_d3_l3000_...
# 30  tree_thompson_sampling_update_v3_r10000_d3_lNo...
# 31  tree_thompson_sampling_update_v3_r10000_d3_lNo...
# 32  tree_thompson_sampling_update_v3_r20_d3_lNone_...
# 33  tree_thompson_sampling_update_v3_r20_d3_lNone_...
# 34                                  thompson_sampling
# 35  tree_thompson_sampling_update_v3_r10_d3_lNone_...
# 36  tree_thompson_sampling_update_v3_r10_d3_lNone_...
# IPS/SNIPS metrics (run_scenarios):
#                                           scenario  \
# 0   case_2b_random_pretrain_online_update_step_2p5
# 1   case_2b_random_pretrain_online_update_step_2p5
# 2   case_2b_random_pretrain_online_update_step_2p5
# 3   case_2b_random_pretrain_online_update_step_2p5
# 4   case_2b_random_pretrain_online_update_step_2p5
# 5   case_2b_random_pretrain_online_update_step_2p5
# 6   case_2b_random_pretrain_online_update_step_2p5
# 7   case_2b_random_pretrain_online_update_step_2p5
# 8   case_2b_random_pretrain_online_update_step_2p5
# 9   case_2b_random_pretrain_online_update_step_2p5
# 10  case_2b_random_pretrain_online_update_step_2p5
# 11  case_2b_random_pretrain_online_update_step_2p5
# 12  case_2b_random_pretrain_online_update_step_2p5
# 13  case_2b_random_pretrain_online_update_step_2p5
# 14  case_2b_random_pretrain_online_update_step_2p5
# 15  case_2b_random_pretrain_online_update_step_2p5
# 16  case_2b_random_pretrain_online_update_step_2p5
# 17  case_2b_random_pretrain_online_update_step_2p5
# 18  case_2b_random_pretrain_online_update_step_2p5
# 19  case_2b_random_pretrain_online_update_step_2p5
# 20  case_2b_random_pretrain_online_update_step_2p5
# 21  case_2b_random_pretrain_online_update_step_2p5
# 22  case_2b_random_pretrain_online_update_step_2p5
# 23  case_2b_random_pretrain_online_update_step_2p5
# 24  case_2b_random_pretrain_online_update_step_2p5
# 25  case_2b_random_pretrain_online_update_step_2p5
# 26  case_2b_random_pretrain_online_update_step_2p5
# 27  case_2b_random_pretrain_online_update_step_2p5
# 28  case_2b_random_pretrain_online_update_step_2p5
# 29  case_2b_random_pretrain_online_update_step_2p5
# 30  case_2b_random_pretrain_online_update_step_2p5
# 31  case_2b_random_pretrain_online_update_step_2p5
# 32  case_2b_random_pretrain_online_update_step_2p5
# 33  case_2b_random_pretrain_online_update_step_2p5
# 34  case_2b_random_pretrain_online_update_step_2p5
# 35  case_2b_random_pretrain_online_update_step_2p5
# 36  case_2b_random_pretrain_online_update_step_2p5
#
#                                                  algo  impressions_total  \
# 0                                   thompson_sampling             648367
# 1   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 2   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 3   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 4   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 5   tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 6   tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 7   tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 8   tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 9   tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 10  tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 11  tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 12  tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 13  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 14  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 15  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 16  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 17  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 18  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 19  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 20  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 21  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
# 22  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
# 23  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
# 24  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
# 25  tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 26  tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 27  tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 28  tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 29  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 30  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 31  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 32  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 33  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
# 34  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
# 35  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
# 36  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
#
#     impressions_extrapolated   ips_ctr  snips_ctr
# 0                   647138.0  0.024130   0.024176
# 1                   647868.0  0.024269   0.024287
# 2                   647868.0  0.024269   0.024287
# 3                   647868.0  0.024269   0.024287
# 4                   647868.0  0.024269   0.024287
# 5                   648320.0  0.024145   0.024147
# 6                   648320.0  0.024145   0.024147
# 7                   648320.0  0.024145   0.024147
# 8                   648320.0  0.024145   0.024147
# 9                   647807.0  0.024230   0.024251
# 10                  647807.0  0.024230   0.024251
# 11                  647810.0  0.024138   0.024158
# 12                  647810.0  0.024138   0.024158
# 13                  647711.0  0.024141   0.024165
# 14                  647711.0  0.024141   0.024165
# 15                  647711.0  0.024141   0.024165
# 16                  647711.0  0.024141   0.024165
# 17                  648489.0  0.024164   0.024159
# 18                  648489.0  0.024164   0.024159
# 19                  648489.0  0.024164   0.024159
# 20                  648489.0  0.024164   0.024159
# 21                  648002.0  0.024119   0.024133
# 22                  648002.0  0.024119   0.024133
# 23                  647554.0  0.024171   0.024202
# 24                  647554.0  0.024171   0.024202
# 25                  647751.0  0.024252   0.024275
# 26                  647751.0  0.024252   0.024275
# 27                  647751.0  0.024252   0.024275
# 28                  647751.0  0.024252   0.024275
# 29                  648522.0  0.024178   0.024172
# 30                  648522.0  0.024178   0.024172
# 31                  648522.0  0.024178   0.024172
# 32                  648522.0  0.024178   0.024172
# 33                  647733.0  0.024164   0.024187
# 34                  647733.0  0.024164   0.024187
# 35                  647988.0  0.024133   0.024147
# 36                  647988.0  0.024133   0.024147
# history rows: 17598180

# %%
display(metrics_df[ips_snips_cols].sort_values(['ips_ctr', 'scenario', 'algo'], ascending=False).reset_index(drop=True).algo.values)
# Out:
# array(['tree_thompson_sampling_update_v3_r10000_d3_l3000_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10000_d3_l3000_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10000_d3_l3000_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10000_d3_l3000_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r20_d3_l3000_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r20_d3_l3000_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r20_d3_l3000_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r20_d3_l3000_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10000_d3_lNone_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10000_d3_lNone_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r20_d3_l5000_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r20_d3_l5000_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r20_d3_l5000_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r20_d3_l5000_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10_d3_lNone_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10_d3_lNone_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r20_d3_lNone_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r20_d3_lNone_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10_d3_l5000_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10_d3_l5000_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10_d3_l5000_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10_d3_l5000_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10000_d3_l5000_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10000_d3_l5000_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10000_d3_l5000_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10000_d3_l5000_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10_d3_l3000_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10_d3_l3000_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10_d3_l3000_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10_d3_l3000_c100_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r10000_d3_lNone_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10000_d3_lNone_c20_fallbackFalse',
#        'tree_thompson_sampling_update_v3_r20_d3_lNone_c20_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r20_d3_lNone_c20_fallbackFalse',
#        'thompson_sampling',
#        'tree_thompson_sampling_update_v3_r10_d3_lNone_c100_fallbackTrue',
#        'tree_thompson_sampling_update_v3_r10_d3_lNone_c100_fallbackFalse'],
#       dtype=object)

# %%
display(metrics_df[ips_snips_cols].sort_values(['ips_ctr', 'scenario', 'algo'], ascending=False).reset_index(drop=True))
# Out:
#                                           scenario  \
# 0   case_2b_random_pretrain_online_update_step_2p5
# 1   case_2b_random_pretrain_online_update_step_2p5
# 2   case_2b_random_pretrain_online_update_step_2p5
# 3   case_2b_random_pretrain_online_update_step_2p5
# 4   case_2b_random_pretrain_online_update_step_2p5
# 5   case_2b_random_pretrain_online_update_step_2p5
# 6   case_2b_random_pretrain_online_update_step_2p5
# 7   case_2b_random_pretrain_online_update_step_2p5
# 8   case_2b_random_pretrain_online_update_step_2p5
# 9   case_2b_random_pretrain_online_update_step_2p5
# 10  case_2b_random_pretrain_online_update_step_2p5
# 11  case_2b_random_pretrain_online_update_step_2p5
# 12  case_2b_random_pretrain_online_update_step_2p5
# 13  case_2b_random_pretrain_online_update_step_2p5
# 14  case_2b_random_pretrain_online_update_step_2p5
# 15  case_2b_random_pretrain_online_update_step_2p5
# 16  case_2b_random_pretrain_online_update_step_2p5
# 17  case_2b_random_pretrain_online_update_step_2p5
# 18  case_2b_random_pretrain_online_update_step_2p5
# 19  case_2b_random_pretrain_online_update_step_2p5
# 20  case_2b_random_pretrain_online_update_step_2p5
# 21  case_2b_random_pretrain_online_update_step_2p5
# 22  case_2b_random_pretrain_online_update_step_2p5
# 23  case_2b_random_pretrain_online_update_step_2p5
# 24  case_2b_random_pretrain_online_update_step_2p5
# 25  case_2b_random_pretrain_online_update_step_2p5
# 26  case_2b_random_pretrain_online_update_step_2p5
# 27  case_2b_random_pretrain_online_update_step_2p5
# 28  case_2b_random_pretrain_online_update_step_2p5
# 29  case_2b_random_pretrain_online_update_step_2p5
# 30  case_2b_random_pretrain_online_update_step_2p5
# 31  case_2b_random_pretrain_online_update_step_2p5
# 32  case_2b_random_pretrain_online_update_step_2p5
# 33  case_2b_random_pretrain_online_update_step_2p5
# 34  case_2b_random_pretrain_online_update_step_2p5
# 35  case_2b_random_pretrain_online_update_step_2p5
# 36  case_2b_random_pretrain_online_update_step_2p5
#
#                                                  algo  impressions_total  \
# 0   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 1   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 2   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 3   tree_thompson_sampling_update_v3_r10000_d3_l30...             648367
# 4   tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 5   tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 6   tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 7   tree_thompson_sampling_update_v3_r20_d3_l3000_...             648367
# 8   tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 9   tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 10  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 11  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 12  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 13  tree_thompson_sampling_update_v3_r20_d3_l5000_...             648367
# 14  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
# 15  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
# 16  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
# 17  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
# 18  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 19  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 20  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 21  tree_thompson_sampling_update_v3_r10_d3_l5000_...             648367
# 22  tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 23  tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 24  tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 25  tree_thompson_sampling_update_v3_r10000_d3_l50...             648367
# 26  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 27  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 28  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 29  tree_thompson_sampling_update_v3_r10_d3_l3000_...             648367
# 30  tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 31  tree_thompson_sampling_update_v3_r10000_d3_lNo...             648367
# 32  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
# 33  tree_thompson_sampling_update_v3_r20_d3_lNone_...             648367
# 34                                  thompson_sampling             648367
# 35  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
# 36  tree_thompson_sampling_update_v3_r10_d3_lNone_...             648367
#
#     impressions_extrapolated   ips_ctr  snips_ctr
# 0                   647868.0  0.024269   0.024287
# 1                   647868.0  0.024269   0.024287
# 2                   647868.0  0.024269   0.024287
# 3                   647868.0  0.024269   0.024287
# 4                   647751.0  0.024252   0.024275
# 5                   647751.0  0.024252   0.024275
# 6                   647751.0  0.024252   0.024275
# 7                   647751.0  0.024252   0.024275
# 8                   647807.0  0.024230   0.024251
# 9                   647807.0  0.024230   0.024251
# 10                  648522.0  0.024178   0.024172
# 11                  648522.0  0.024178   0.024172
# 12                  648522.0  0.024178   0.024172
# 13                  648522.0  0.024178   0.024172
# 14                  647554.0  0.024171   0.024202
# 15                  647554.0  0.024171   0.024202
# 16                  647733.0  0.024164   0.024187
# 17                  647733.0  0.024164   0.024187
# 18                  648489.0  0.024164   0.024159
# 19                  648489.0  0.024164   0.024159
# 20                  648489.0  0.024164   0.024159
# 21                  648489.0  0.024164   0.024159
# 22                  648320.0  0.024145   0.024147
# 23                  648320.0  0.024145   0.024147
# 24                  648320.0  0.024145   0.024147
# 25                  648320.0  0.024145   0.024147
# 26                  647711.0  0.024141   0.024165
# 27                  647711.0  0.024141   0.024165
# 28                  647711.0  0.024141   0.024165
# 29                  647711.0  0.024141   0.024165
# 30                  647810.0  0.024138   0.024158
# 31                  647810.0  0.024138   0.024158
# 32                  647988.0  0.024133   0.024147
# 33                  647988.0  0.024133   0.024147
# 34                  647138.0  0.024130   0.024176
# 35                  648002.0  0.024119   0.024133
# 36                  648002.0  0.024119   0.024133

# %% [markdown]
# ## 4.1) SNIPS по action / policy
# Таблица строится сразу после запуска benchmark и показывает per-action SNIPS-агрегацию.

# %%
if not action_ips_stats_df.empty:
    action_snips_table_df = (
        action_ips_stats_df
        .rename(columns={
            'algo': 'policy',
            'ips_weighted_reward': 'sum_snips_reward',
            'impressions_extrapolated': 'sum_snips_show',
            'snips_ctr': 'snips',
        })[['action', 'policy', 'sum_snips_reward', 'sum_snips_show', 'snips']]
        .sort_values(['action', 'policy'])
        .reset_index(drop=True)
    )
    display(action_snips_table_df)
else:
    print('action_ips_stats_df is empty.')

# %% [markdown]
# ## 4.2) Запуск off-policy IPS/SNIPS (`run_scenarios_ips`)
# Отдельный прогон с использованием `get_action_proba` вместо `select`.

# %%
result_offpolicy = run_scenarios_ips(
    train_df=train_eval_df,
    test_df=test_eval_df,
    policy_factories=policy_factories,
    scenarios=scenarios,
    show_progress=True,
)
metrics_offpolicy_df = result_offpolicy['metrics']
history_offpolicy_df = result_offpolicy['history']
action_stats_offpolicy_df = result_offpolicy['action_stats']
action_daily_stats_offpolicy_df = result_offpolicy['action_daily_stats']
action_ips_stats_offpolicy_df = result_offpolicy['action_ips_stats']

display(metrics_offpolicy_df.sort_values('ips_ctr', ascending=False).reset_index(drop=True))

ips_snips_cols = ['scenario', 'algo', 'impressions_total', 'impressions_extrapolated', 'ips_ctr', 'snips_ctr']
if set(ips_snips_cols).issubset(metrics_offpolicy_df.columns):
    print('IPS/SNIPS metrics (off-policy propensity):')
    display(metrics_offpolicy_df[ips_snips_cols].sort_values(['scenario', 'algo']).reset_index(drop=True))

print('offpolicy history rows:', len(history_offpolicy_df))

# %% [markdown]
# ## 4.3) Bootstrap для IPS/SNIPS
# Запускает `run_scenarios_ips` на bootstrap-выборках test и считает средние метрики с доверительными интервалами.

# %%
bootstrap_summary_df = pd.DataFrame()
bootstrap_runs_df = pd.DataFrame()

if BOOTSTRAP_ENABLED:
    alpha = 1.0 - BOOTSTRAP_CI
    bootstrap_metrics_parts = []

    for i in range(BOOTSTRAP_ITERATIONS):
        boot_test_df = test_eval_df.sample(
            fraction=1.0,
            with_replacement=True,
            shuffle=True,
            seed=SEED + i,
        )
        boot_result = run_scenarios_ips(
            train_df=train_eval_df,
            test_df=boot_test_df,
            policy_factories=policy_factories,
            scenarios=scenarios,
            show_progress=False,
        )
        boot_metrics = boot_result['metrics'][['scenario', 'algo', 'impressions_total', 'impressions_extrapolated', 'ips_ctr', 'snips_ctr']].copy()
        boot_metrics['extrapolated_ratio'] = boot_metrics['impressions_extrapolated'] / boot_metrics['impressions_total']
        boot_metrics['bootstrap_iter'] = i
        bootstrap_metrics_parts.append(boot_metrics)

    bootstrap_runs_df = pd.concat(bootstrap_metrics_parts, ignore_index=True)

    bootstrap_summary_df = (
        bootstrap_runs_df
        .groupby(['scenario', 'algo'], as_index=False)
        .agg(
            ips_ctr_mean=('ips_ctr', 'mean'),
            ips_ctr_ci_low=('ips_ctr', lambda s: s.quantile(alpha / 2)),
            ips_ctr_ci_high=('ips_ctr', lambda s: s.quantile(1 - alpha / 2)),
            snips_ctr_mean=('snips_ctr', 'mean'),
            snips_ctr_ci_low=('snips_ctr', lambda s: s.quantile(alpha / 2)),
            snips_ctr_ci_high=('snips_ctr', lambda s: s.quantile(1 - alpha / 2)),
            extrapolated_ratio_mean=('extrapolated_ratio', 'mean'),
            extrapolated_ratio_ci_low=('extrapolated_ratio', lambda s: s.quantile(alpha / 2)),
            extrapolated_ratio_ci_high=('extrapolated_ratio', lambda s: s.quantile(1 - alpha / 2)),
        )
        .sort_values(['scenario', 'algo'])
        .reset_index(drop=True)
    )

    print(f'Bootstrap iterations: {BOOTSTRAP_ITERATIONS}, CI: {BOOTSTRAP_CI:.0%}')
    display(bootstrap_summary_df)
else:
    print('Bootstrap is disabled. Set BOOTSTRAP_ENABLED=True to run.')

# %% [markdown]
# ## 5) Графики по сценариям

# %%
if not history_df.empty:
    for scenario_name, part in history_df.groupby('scenario'):
        fig, axes = plt.subplots(2, 2, figsize=(14, 8))

        for algo, algo_df in part.groupby('algo'):
            max_step = int(algo_df['step'].max()) if len(algo_df) else 0
            stride = max(1, int(round(max_step * 0.05)))  # каждые 5%
            ds = algo_df.iloc[stride::stride] if len(algo_df) > stride else algo_df  # стартуем с 5%

            axes[0, 0].plot(ds['step'], ds['avg_reward'], label=algo)
            axes[0, 1].plot(ds['step'], ds['avg_regret'], label=algo)
            axes[1, 0].plot(ds['step'], ds['ips_avg_reward'], label=algo)
            axes[1, 1].plot(ds['step'], ds['avg_ips_regret'], label=algo)

        axes[0, 0].set_title(f'{scenario_name}: average reward')
        axes[0, 0].set_xlabel('step')
        axes[0, 0].set_ylabel('avg_reward')

        axes[0, 1].set_title(f'{scenario_name}: average regret')
        axes[0, 1].set_xlabel('step')
        axes[0, 1].set_ylabel('avg_regret')

        axes[1, 0].set_title(f'{scenario_name}: IPS average reward')
        axes[1, 0].set_xlabel('step')
        axes[1, 0].set_ylabel('ips_avg_reward')

        axes[1, 1].set_title(f'{scenario_name}: IPS average regret')
        axes[1, 1].set_xlabel('step')
        axes[1, 1].set_ylabel('avg_ips_regret')

        for ax in axes.ravel():
            ax.grid(True, alpha=0.3)
            ax.legend()

        fig.tight_layout()
        plt.show()
else:
    print('History is empty.')

# %% [markdown]
# ## 6) Per-action SNIPS table moved выше
# Отдельный bar-plot удалён; вместо него таблица `action / policy / sum_snips_reward / sum_snips_show / snips` выводится сразу после секции 4.

# %%
print('Per-action SNIPS table is displayed above, right after section 4.')

# %% [markdown]
# ## 6.1) Sensitive IPS метрики убраны
# Этот блок оставлен только как пометка: sensitive-метрики больше не считаются и не визуализируются.

# %%
print('Sensitive IPS history plots removed.')

# %% [markdown]
# ## 7) Графики по статистикам action'ов
# Показывает динамику общего числа уникальных action'ов и количества новых action'ов по дням/checkpoint'ам.

# %%
if not action_stats_df.empty:
    for scenario_name, part in action_stats_df.groupby('scenario'):
        fig, axes = plt.subplots(1, 2, figsize=(14, 4))

        for algo, algo_df in part.groupby('algo'):
            algo_df = algo_df.sort_values('step')
            axes[0].plot(algo_df['step'], algo_df['unique_actions_total'], label=algo)
            axes[1].plot(algo_df['step'], algo_df['unique_actions_new_in_day'], label=algo)

        axes[0].set_title(f"{scenario_name}: unique actions total")
        axes[0].set_xlabel('step')
        axes[0].set_ylabel('unique_actions_total')

        axes[1].set_title(f"{scenario_name}: new actions in day")
        axes[1].set_xlabel('step')
        axes[1].set_ylabel('unique_actions_new_in_day')

        for ax in axes:
            ax.grid(True, alpha=0.3)
            ax.legend()

        fig.tight_layout()
        plt.show()
else:
    print('action_stats_df is empty.')

# %% [markdown]
# ## 8) Распределение показов по action и дням

# %%
if not action_daily_stats_df.empty:
    top_actions_n = 12

    for scenario_name, part in action_daily_stats_df.groupby('scenario'):
        for algo_name, algo_df in part.groupby('algo'):
            pivot_cnt = algo_df.pivot_table(index='date', columns='action', values='impressions_selected', aggfunc='sum').fillna(0)

            if pivot_cnt.shape[1] > top_actions_n:
                action_totals = pivot_cnt.sum(axis=0).sort_values(ascending=False)
                top_actions = action_totals.head(top_actions_n).index
                other_actions = [a for a in pivot_cnt.columns if a not in top_actions]

                plot_df = pivot_cnt.loc[:, top_actions].copy()
                if other_actions:
                    plot_df['other_actions'] = pivot_cnt.loc[:, other_actions].sum(axis=1)
            else:
                plot_df = pivot_cnt.copy()

            fig, ax = plt.subplots(figsize=(12, 4))
            plot_df.sort_index().plot(ax=ax)
            ax.set_title(f'{scenario_name}/{algo_name}: impressions selected by action/day')
            ax.set_xlabel('date')
            ax.set_ylabel('impressions_selected')
            ax.grid(True, alpha=0.3)
            ax.legend(loc='upper left', bbox_to_anchor=(1.01, 1), title='action')
            fig.tight_layout()
            plt.show()
else:
    print('action_daily_stats_df is empty.')

# %% [markdown]
# ## 9) Сохранение артефактов

# %%
OUT_DIR = ARTIFACTS_DIR
OUT_DIR.mkdir(parents=True, exist_ok=True)

metrics_path = OUT_DIR / 'metrics.csv'
history_path = OUT_DIR / 'history.csv'
metrics_offpolicy_path = OUT_DIR / 'metrics_offpolicy.csv'
action_stats_path = OUT_DIR / 'action_stats.csv'
action_daily_stats_path = OUT_DIR / 'action_daily_stats.csv'
action_ips_stats_path = OUT_DIR / 'action_ips_stats.csv'
action_ips_stats_offpolicy_path = OUT_DIR / 'action_ips_stats_offpolicy.csv'

metrics_df.to_csv(metrics_path, index=False)
history_df.to_csv(history_path, index=False)
metrics_offpolicy_df.to_csv(metrics_offpolicy_path, index=False)
action_stats_df.to_csv(action_stats_path, index=False)
action_daily_stats_df.to_csv(action_daily_stats_path, index=False)
action_ips_stats_df.to_csv(action_ips_stats_path, index=False)
action_ips_stats_offpolicy_df.to_csv(action_ips_stats_offpolicy_path, index=False)

print('saved metrics:', metrics_path)
print('saved history:', history_path)
print('saved offpolicy metrics:', metrics_offpolicy_path)
print('saved action stats:', action_stats_path)
print('saved action daily stats:', action_daily_stats_path)
print('saved action IPS stats:', action_ips_stats_path)
print('saved offpolicy action IPS stats:', action_ips_stats_offpolicy_path)

bootstrap_summary_path = OUT_DIR / 'bootstrap_summary.csv'
bootstrap_runs_path = OUT_DIR / 'bootstrap_runs.csv'

if not bootstrap_summary_df.empty:
    bootstrap_summary_df.to_csv(bootstrap_summary_path, index=False)
    print('saved bootstrap summary:', bootstrap_summary_path)
if not bootstrap_runs_df.empty:
    bootstrap_runs_df.to_csv(bootstrap_runs_path, index=False)
    print('saved bootstrap runs:', bootstrap_runs_path)
